# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

from shapely.geometry import Point, Polygon
import geopandas as gpd

# %%
from matplotlib.colors import LinearSegmentedColormap

# %%
df = pd.read_csv('../data/mag/own_medsale_canafford_FHA_all.csv')

# %%
df.columns
# Out:
# Index(['puma', 'can_tot', 'cant_tot', 'can_buy', 'cant_buy', 'med_val'], dtype='object')

# %% [markdown]
# ## map percent that can/can't by neighborhood

# %%
# allow max rows and colums to be displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
geo = gpd.read_file('../data/geo/shapefiles/PUMAS.geojson')
#geo.head(2)

# %%
phx = gpd.read_file('../data/geo/shapefiles/phx.geojson')
villages = gpd.read_file('../data/geo/shapefiles/Villages.shp')
villages = villages.to_crs(4269)
road = gpd.read_file('../data/geo/shapefiles/maricopa_primroads.geojson')
road = road.to_crs(4269)
mask = gpd.read_file('../data/geo/shapefiles/PUMAS_mask.geojson')

# %% [markdown]
# ### join data to geo files

# %%
df = pd.merge(geo,df,how='left',left_on='joinid',right_on='puma')

# %%
df.head(2)
# Out:
#   STATEFP20 PUMACE20  GEOID20  \
# 0        04    00129  0400129
# 1        04    00112  0400112
#
#                                           NAMELSAD20 MTFCC20 FUNCSTAT20  \
# 0  Phoenix (Far North) & Peoria (Northwest) Citie...   G6120          S
# 1  Maricopa County--Scottsdale (North), Phoenix (...   G6120          S
#
#      ALAND20  AWATER20   INTPTLAT20    INTPTLON20  joinid  \
# 0  654040399   3894959  +33.8457815  -112.1641828  400129
# 1  608391353    434248  +33.7670066  -111.9328706  400112
#
#                                             geometry    puma  can_tot  \
# 0  MULTIPOLYGON (((-112.04763 33.71469, -112.0475...  400129    91265
# 1  MULTIPOLYGON (((-111.78744 33.68347, -111.7874...  400112    46444
#
#    cant_tot   can_buy  cant_buy  med_val
# 0    456462  0.166625  0.833375   518000
# 1    501283  0.084794  0.915206   725000

# %%
df.describe()
# Out:
#             ALAND20      AWATER20         joinid           puma  \
# count  1.500000e+01  1.500000e+01      15.000000      15.000000
# mean   1.500315e+08  4.751324e+05  400119.466667  400119.466667
# std    1.990223e+08  9.764382e+05       5.235411       5.235411
# min    3.348861e+07  2.684700e+04  400112.000000  400112.000000
# 25%    5.061796e+07  7.029600e+04  400115.500000  400115.500000
# 50%    7.508780e+07  1.879480e+05  400119.000000  400119.000000
# 75%    1.181456e+08  3.115855e+05  400122.500000  400122.500000
# max    6.540404e+08  3.894959e+06  400129.000000  400129.000000
#
#              can_tot       cant_tot    can_buy   cant_buy        med_val
# count      15.000000      15.000000  15.000000  15.000000      15.000000
# mean   163117.866667  384609.133333   0.297809   0.702191  398862.066667
# std     61313.036092   61313.036092   0.111941   0.111941  123575.672351
# min     46444.000000  281061.000000   0.084794   0.513141  250000.000000
# 25%    114744.500000  354834.000000   0.209492   0.647830  332000.000000
# 50%    175457.000000  372270.000000   0.320337   0.679663  358710.000000
# 75%    192893.000000  432982.500000   0.352170   0.790508  462500.000000
# max    266666.000000  501283.000000   0.486859   0.915206  725000.000000

# %%
# percent can buy
fig, ax = plt.subplots(1, figsize = (20,16))
ax.axis('off')
new_norm = plt.Normalize(vmin=0.0,vmax=0.5)
sm = plt.cm.ScalarMappable(cmap='YlGnBu', norm=new_norm)
sm.set_array([])
phx.plot(ax=ax,color='whitesmoke',edgecolor='black',linewidth=0)
df.plot(column = f'can_buy', cmap='YlGnBu', norm=new_norm, edgecolor="white", linewidth=0.0, ax=ax)
mask.plot(ax=ax,color='none',edgecolor='white',linewidth=0.1,hatch='//////')
villages.plot(ax=ax,color='none',edgecolor='white',linewidth=0.4,linestyle='dashed')
phx.plot(ax=ax,color='none',edgecolor='black',linewidth=1.0,linestyle='dashdot')
road.plot(ax=ax,color='black',edgecolor='black',linewidth=0.6)
fig.colorbar(sm)
plt.savefig('img/can_buy_FHA_ylgnbu_50pct.jpg', dpi = 300) # saving each plot

# %%
# percent can buy
fig, ax = plt.subplots(1, figsize = (20,16))
ax.axis('off')
new_norm = plt.Normalize(vmin=0.5,vmax=.85)
sm = plt.cm.ScalarMappable(cmap='YlGnBu', norm=new_norm)
sm.set_array([])
phx.plot(ax=ax,color='whitesmoke',edgecolor='black',linewidth=0)
df.plot(column = f'cant_buy', cmap='YlGnBu', norm=new_norm, edgecolor="white", linewidth=0.0, ax=ax)
mask.plot(ax=ax,color='none',edgecolor='white',linewidth=0.1,hatch='//////')
villages.plot(ax=ax,color='none',edgecolor='white',linewidth=0.4,linestyle='dashed')
phx.plot(ax=ax,color='none',edgecolor='black',linewidth=1.0,linestyle='dashdot')
road.plot(ax=ax,color='black',edgecolor='black',linewidth=0.6)
fig.colorbar(sm)
plt.savefig(f'img/cant_buy_FHA_ylgnbu_50pct.jpg', dpi = 300) # saving each plot

# %% [markdown]
# ## median sales value

# %%
## setting custom color gradient
blue_green_orange = LinearSegmentedColormap.from_list('blue_green_orange', (
    # Edit this gradient at https://eltos.github.io/gradient/#blue_gr_or=213A4F-318AD8-5CDDBF-D89900-995111
    (0.000, (0.129, 0.227, 0.310)),
    (0.250, (0.192, 0.541, 0.847)),
    (0.500, (0.361, 0.867, 0.749)),
    (0.750, (0.847, 0.600, 0.000)),
    (1.000, (0.600, 0.318, 0.067))))


if __name__ == '__main__':
    import numpy as np
    from matplotlib import pyplot as plt
    
    plt.imshow([np.arange(1000)], aspect="auto", cmap=blue_green_orange)
    plt.show()

# %%
blue_yl_red =LinearSegmentedColormap.from_list('blue_ylw_red', (
    # Edit this gradient at https://eltos.github.io/gradient/#blue_ylw_red=334A5E-3680C1-D2DA03-D86400-C84800
    (0.000, (0.200, 0.290, 0.369)),
    (0.250, (0.212, 0.502, 0.757)),
    (0.500, (0.824, 0.855, 0.012)),
    (0.750, (0.847, 0.392, 0.000)),
    (1.000, (0.784, 0.282, 0.000))))

blue_or = LinearSegmentedColormap.from_list('blue_or', (
    # Edit this gradient at https://eltos.github.io/gradient/#blue_or=273948-3680C1-BE9ECF-D87300-995111
    (0.000, (0.153, 0.224, 0.282)),
    (0.250, (0.212, 0.502, 0.757)),
    (0.500, (0.745, 0.620, 0.812)),
    (0.750, (0.847, 0.451, 0.000)),
    (1.000, (0.600, 0.318, 0.067))))

# %%
# percent can buy
fig, ax = plt.subplots(1, figsize = (20,16))
ax.axis('off')
new_norm = plt.Normalize(vmin=250000,vmax=600000)
sm = plt.cm.ScalarMappable(cmap=blue_green_orange, norm=new_norm)
sm.set_array([])
phx.plot(ax=ax,color='whitesmoke',edgecolor='black',linewidth=0)
df.plot(column = f'med_val', cmap=blue_green_orange, norm=new_norm, edgecolor="white", linewidth=0.0, ax=ax)
mask.plot(ax=ax,color='none',edgecolor='white',linewidth=0.1,hatch='//////')
villages.plot(ax=ax,color='none',edgecolor='white',linewidth=0.4,linestyle='dashed')
phx.plot(ax=ax,color='none',edgecolor='black',linewidth=1.0,linestyle='dashdot')
road.plot(ax=ax,color='black',edgecolor='black',linewidth=0.6)
fig.colorbar(sm)
plt.savefig(f'img/med_sales_val_fha.jpg', dpi = 300) # saving each plot
